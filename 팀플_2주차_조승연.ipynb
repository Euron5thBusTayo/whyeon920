# %%
#디렉터리 설정
from google.colab import drive
drive.mount('/content/gdrive/')

path = "/content/gdrive/My Drive/EuronData"
# Out:
# Mounted at /content/gdrive/

# %% [markdown]
# # 데이터를 불러오자!

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

import seaborn as sns

# %%
import pandas as pd
import numpy as np

train = pd.read_csv(path + '/bus_train/2022년_버스노선별_정류장별_시간대별_승하차_인원_정보(09월).csv', encoding='cp949')
test = pd.read_csv(path + '/bus_test/2023년_버스노선별_정류장별_시간대별_승하차_인원_정보(09월).csv', encoding='cp949')
# Out:
# <ipython-input-3-1baab9f6a6d2>:4: DtypeWarning: Columns (4) have mixed types. Specify dtype option on import or set low_memory=False.
#   train = pd.read_csv(path + '/bus_train/2022년_버스노선별_정류장별_시간대별_승하차_인원_정보(09월).csv', encoding='cp949')
# <ipython-input-3-1baab9f6a6d2>:5: DtypeWarning: Columns (4) have mixed types. Specify dtype option on import or set low_memory=False.
#   test = pd.read_csv(path + '/bus_test/2023년_버스노선별_정류장별_시간대별_승하차_인원_정보(09월).csv', encoding='cp949')

# %%
train
# Out:
#          사용년월  노선번호                    노선명  표준버스정류장ID 버스정류장ARS번호  \
# 0      202209   741      741번(진관차고지~헌인릉입구)  100000001       1001
# 1      202209   470       470번(상암차고지~안골마을)  100000001       1001
# 2      202209   N37  N37번(송파공영차고지~진관공영차고지)  100000001       1001
# 3      202209   N37  N37번(진관공영차고지~송파공영차고지)  100000001       1001
# 4      202209   100         100번(하계동~용산구청)  100000002       1002
# ...       ...   ...                    ...        ...        ...
# 40817  202209   672         672번(방화동~이대후문)  999800002          ~
# 40818  202209  9404        9404번(분당구미~신사역)  999800003          ~
# 40819  202209  9404        9404번(분당구미~신사역)  999800004          ~
# 40820  202209  9701         9701번(가좌동~서울역)  999800005          ~
# 40821  202209  9707     9707번(고양 가좌동~영등포역)  999800005          ~
#
#                         역명  00시승차총승객수  00시하차총승객수  1시승차총승객수  1시하차총승객수  ...  \
# 0           종로2가사거리(00077)         92         77       105       118  ...
# ...

# %%
test
# Out:
#          사용년월  노선번호                    노선명  표준버스정류장ID 버스정류장ARS번호  \
# 0      202309   N37  N37번(송파공영차고지~진관공영차고지)  100000001       1001
# 1      202309   470       470번(상암차고지~안골마을)  100000001       1001
# 2      202309   N37  N37번(진관공영차고지~송파공영차고지)  100000001       1001
# 3      202309   741      741번(진관차고지~헌인릉입구)  100000001       1001
# 4      202309   100         100번(하계동~용산구청)  100000002       1002
# ...       ...   ...                    ...        ...        ...
# 41569  202309   672         672번(방화동~이대후문)  999800002          ~
# 41570  202309  9404        9404번(분당구미~신사역)  999800003          ~
# 41571  202309  9404        9404번(분당구미~신사역)  999800004          ~
# 41572  202309  9701         9701번(가좌동~서울역)  999800005          ~
# 41573  202309  9707     9707번(고양 가좌동~영등포역)  999800005          ~
#
#                         역명  00시승차총승객수  00시하차총승객수  1시승차총승객수  1시하차총승객수  ...  \
# 0           종로2가사거리(00032)         11         18       168       236  ...
# ...

# %%
#for i in range(10, 13):
#  if i <10:
#    train_i = pd.read_csv(path + '/bus_train/2022년_버스노선별_정류장별_시간대별_승하차_인원_정보(09월)')
#    train = pd.concat([train, train_i])
#  else:
#    train_i = pd.read_csv(path + '/bus_train/2022년_버스노선별_정류장별_시간대별_승하차_인원_정보(' + i + '월)')
#    train = pd.concat([train, train_i])
#for i in range(1, 9):
#  train_i = pd.read_csv(path + '/bus_train/2023년_버스노선별_정류장별_시간대별_승하차_인원_정보(0' + i + '월)')
#  train = pd.concat([train, train_i])

# %%
for i in range(10, 13):
  train_i = pd.read_csv(path + '/bus_train/2022년_버스노선별_정류장별_시간대별_승하차_인원_정보(' + str(i) + '월).csv', encoding='cp949')
  train = pd.concat([train, train_i])
for i in range(1, 9):
  train_i = pd.read_csv(path + '/bus_train/2023년_버스노선별_정류장별_시간대별_승하차_인원_정보(0' + str(i) + '월).csv', encoding='cp949')
  train = pd.concat([train, train_i])
# Out:
# <ipython-input-6-2511b223fdfb>:2: DtypeWarning: Columns (4) have mixed types. Specify dtype option on import or set low_memory=False.
#   train_i = pd.read_csv(path + '/bus_train/2022년_버스노선별_정류장별_시간대별_승하차_인원_정보(' + str(i) + '월).csv', encoding='cp949')
# <ipython-input-6-2511b223fdfb>:2: DtypeWarning: Columns (4) have mixed types. Specify dtype option on import or set low_memory=False.
#   train_i = pd.read_csv(path + '/bus_train/2022년_버스노선별_정류장별_시간대별_승하차_인원_정보(' + str(i) + '월).csv', encoding='cp949')
# <ipython-input-6-2511b223fdfb>:2: DtypeWarning: Columns (4) have mixed types. Specify dtype option on import or set low_memory=False.
#   train_i = pd.read_csv(path + '/bus_train/2022년_버스노선별_정류장별_시간대별_승하차_인원_정보(' + str(i) + '월).csv', encoding='cp949')
# <ipython-input-6-2511b223fdfb>:5: DtypeWarning: Columns (4) have mixed types. Specify dtype option on import or set low_memory=False.
# ...

# %%
train
# Out:
#          사용년월  노선번호                    노선명  표준버스정류장ID 버스정류장ARS번호  \
# 0      202209   741      741번(진관차고지~헌인릉입구)  100000001       1001
# 1      202209   470       470번(상암차고지~안골마을)  100000001       1001
# 2      202209   N37  N37번(송파공영차고지~진관공영차고지)  100000001       1001
# 3      202209   N37  N37번(진관공영차고지~송파공영차고지)  100000001       1001
# 4      202209   100         100번(하계동~용산구청)  100000002       1002
# ...       ...   ...                    ...        ...        ...
# 41645  202308   672         672번(방화동~이대후문)  999800002          ~
# 41646  202308  9404        9404번(분당구미~신사역)  999800003          ~
# 41647  202308  9404        9404번(분당구미~신사역)  999800004          ~
# 41648  202308  9707     9707번(고양 가좌동~영등포역)  999800005          ~
# 41649  202308  9701         9701번(가좌동~서울역)  999800005          ~
#
#                         역명  00시승차총승객수  00시하차총승객수  1시승차총승객수  1시하차총승객수  ...  \
# 0           종로2가사거리(00077)         92         77       105       118  ...
# ...

# %%
for i in range(10, 12):
  test_i = pd.read_csv(path + '/bus_test/2023년_버스노선별_정류장별_시간대별_승하차_인원_정보(' + str(i) + '월).csv', encoding='cp949')
  test = pd.concat([test, test_i])
# Out:
# <ipython-input-8-6b2e71ea8825>:2: DtypeWarning: Columns (4) have mixed types. Specify dtype option on import or set low_memory=False.
#   test_i = pd.read_csv(path + '/bus_test/2023년_버스노선별_정류장별_시간대별_승하차_인원_정보(' + str(i) + '월).csv', encoding='cp949')
# <ipython-input-8-6b2e71ea8825>:2: DtypeWarning: Columns (4) have mixed types. Specify dtype option on import or set low_memory=False.
#   test_i = pd.read_csv(path + '/bus_test/2023년_버스노선별_정류장별_시간대별_승하차_인원_정보(' + str(i) + '월).csv', encoding='cp949')

# %%
test
# Out:
#          사용년월  노선번호                    노선명  표준버스정류장ID 버스정류장ARS번호  \
# 0      202309   N37  N37번(송파공영차고지~진관공영차고지)  100000001       1001
# 1      202309   470       470번(상암차고지~안골마을)  100000001       1001
# 2      202309   N37  N37번(진관공영차고지~송파공영차고지)  100000001       1001
# 3      202309   741      741번(진관차고지~헌인릉입구)  100000001       1001
# 4      202309   100         100번(하계동~용산구청)  100000002       1002
# ...       ...   ...                    ...        ...        ...
# 41559  202311   672         672번(방화동~이대후문)  999800002          ~
# 41560  202311  9404        9404번(분당구미~신사역)  999800003          ~
# 41561  202311  9404        9404번(분당구미~신사역)  999800004          ~
# 41562  202311  9701         9701번(가좌동~서울역)  999800005          ~
# 41563  202311  9707     9707번(고양 가좌동~영등포역)  999800005          ~
#
#                         역명  00시승차총승객수  00시하차총승객수  1시승차총승객수  1시하차총승객수  ...  \
# 0           종로2가사거리(00032)         11         18       168       236  ...
# ...

# %%
weather_temp = pd.read_csv(path + '/extremum_20240124022608.csv', skiprows = 11, encoding='cp949')
weather_temp
# Out:
#     \t\t지점번호 지점명       일시  평균기온(℃)  평균최고기온(℃)  최고기온(℃)    \t최고기온일자  평균최저기온(℃)  \
# 0        108  서울  2022-01     -2.2        2.6      8.4  2022-01-24       -6.2
# 1        108  서울  2022-02     -1.1        3.8     11.5  2022-02-28       -5.3
# 2        108  서울  2022-03      7.7       12.7     19.5  2022-03-12        3.2
# 3        108  서울  2022-04     14.8       20.6     28.7  2022-04-26       10.0
# 4        108  서울  2022-05     19.1       25.0     30.7  2022-05-23       13.9
# 5        108  서울  2022-06     23.3       27.5     32.7  2022-06-11       19.8
# 6        108  서울  2022-07     27.3       31.0     36.1  2022-07-30       24.2
# 7        108  서울  2022-08     25.7       28.9     32.9  2022-08-04       23.1
# 8        108  서울  2022-09     22.4       27.2     32.5  2022-09-18       18.2
# 9        108  서울  2022-10     14.6       19.7     27.6  2022-10-01       10.3
# 10       108  서울  2022-11     10.0       15.4     22.1  2022-11-11        5.6
# ...

# %%
weather_rain = pd.read_csv(path + '/extremum_20240124165040.csv', skiprows = 12, encoding='cp949')
weather_rain
# Out:
#     \t지점번호 지점명       일시  강수량(mm)  일최다강수량(mm)    일최다강수량일자  1시간최다강수량(mm)  \
# 0      108  서울  2022-01      5.5         1.7  2022-01-19           NaN
# 1      108  서울  2022-02      4.7         1.7  2022-02-14           NaN
# 2      108  서울  2022-03    102.6        42.1  2022-03-13           NaN
# 3      108  서울  2022-04     20.4        15.5  2022-04-29           4.0
# 4      108  서울  2022-05      7.5         3.5  2022-05-25           2.9
# 5      108  서울  2022-06    393.8       176.2  2022-06-30          34.4
# 6      108  서울  2022-07    252.3       114.5  2022-07-13          33.8
# 7      108  서울  2022-08    564.8       129.6  2022-08-08          47.1
# 8      108  서울  2022-09    201.5       120.0  2022-09-05          12.8
# 9      108  서울  2022-10    124.1        76.0  2022-10-03          14.7
# 10     108  서울  2022-11     84.5        57.9  2022-11-12           NaN
# 11     108  서울  2022-12     13.6         5.4  2022-12-12           NaN
# ...

# %% [markdown]
# # 데이터를 가공하자!

# %%
bus_replace = train.groupby('버스정류장ARS번호')['표준버스정류장ID'].nunique().sort_values()
bus_replace
# Out:
# 버스정류장ARS번호
# 1001      1
# 21889     1
# 21890     1
# 21891     1
# 21892     1
#          ..
# 68223     2
# 38069     2
# 22614     2
# 00000     4
# ~        82
# Name: 표준버스정류장ID, Length: 13157, dtype: int64

# %%
bus_replace = train.groupby('표준버스정류장ID')['버스정류장ARS번호'].nunique().sort_values()
bus_replace
# Out:
# 표준버스정류장ID
# 100000001    1
# 119900212    1
# 119900213    1
# 119900214    1
# 119900215    1
#             ..
# 121900215    2
# 121900214    2
# 121900213    2
# 121900242    2
# 122000086    2
# Name: 버스정류장ARS번호, Length: 12796, dtype: int64

# %% [markdown]
# -> 표준버스정류장ID와 버스정류장 ARS 번호가 어느정도 매치하긴 하지만... 아예 완전 완벽히 퍼펙트 일대일대응이 아니므로 우선 남겨둠!

# %%
bus_replace = train.groupby('표준버스정류장ID')['역명'].nunique().sort_values()
bus_replace
# Out:
# 표준버스정류장ID
# 115900093     1
# 204000087     1
# 204000093     1
# 204000097     1
# 112900260     1
#              ..
# 121000114    32
# 118000004    33
# 113000073    34
# 121000013    35
# 107000002    36
# Name: 역명, Length: 12796, dtype: int64

# %%
bus_replace = train.groupby('버스정류장ARS번호')['역명'].nunique().sort_values()
bus_replace
# Out:
# 버스정류장ARS번호
# 12812      1
# 17755      1
# 17772      1
# 17773      1
# 17792      1
#         ...
# 19004     33
# 14164     34
# 22013     35
# 8002      36
# ~        176
# Name: 역명, Length: 13157, dtype: int64

# %%
#불필요 칼럼 제거
train.drop(labels=['등록일자'],axis=1,inplace=True)
test.drop(labels=['등록일자'],axis=1,inplace=True)

# %% [markdown]
# ## 버스 타입 정의

# %%
train['교통수단타입명'].value_counts()
# Out:
# 서울지선버스    192368
# 서울간선버스    155269
# 서울마을버스     91303
# 서울심야버스     47646
# 서울광역버스     11229
# 서울순환버스       361
# Name: 교통수단타입명, dtype: int64

# %%
train['교통수단타입코드'].value_counts()
# Out:
# 20    192368
# 10    155269
# 30     91303
# 51     47646
# 50     11229
# 40       361
# Name: 교통수단타입코드, dtype: int64

# %%
bus_replace = train.groupby('교통수단타입명')['교통수단타입코드'].nunique().sort_values()
bus_replace
# Out:
# 교통수단타입명
# 서울간선버스    1
# 서울광역버스    1
# 서울마을버스    1
# 서울순환버스    1
# 서울심야버스    1
# 서울지선버스    1
# Name: 교통수단타입코드, dtype: int64

# %%
#교통수단 타입코드와 교통수단 타입명이 같은 것으로 보임. 따라서 교통수단 타입코드 칼럼을 제거.
train.drop(labels=['교통수단타입코드'],axis=1,inplace=True)
test.drop(labels=['교통수단타입코드'],axis=1,inplace=True)

# %%
test['교통수단타입명'].value_counts()
# Out:
# 서울지선버스    48414
# 서울간선버스    39169
# 서울마을버스    22931
# 서울심야버스    12430
# 서울광역버스     2472
# 서울순환버스      160
# Name: 교통수단타입명, dtype: int64

# %%
#야간버스 행 드롭
train = train[train['교통수단타입명'] != '서울심야버스']
test = test[test['교통수단타입명'] != '서울심야버스']

# %%
train['교통수단타입명'].value_counts()
# Out:
# 서울지선버스    192368
# 서울간선버스    155269
# 서울마을버스     91303
# 서울광역버스     11229
# 서울순환버스       361
# Name: 교통수단타입명, dtype: int64

# %%
sum(train['교통수단타입명'] == '서울마을버스')
# Out:
# 91303

# %%
#지선+간선+순환/마을/광역
train.loc[train['교통수단타입명'] == '서울지선버스', '버스타입'] = '시내버스'
train.loc[train['교통수단타입명'] == '서울간선버스', '버스타입'] = '시내버스'
train.loc[train['교통수단타입명'] == '서울마을버스', '버스타입'] = '마을버스'
train.loc[train['교통수단타입명'] == '서울광역버스', '버스타입'] = '광역버스'
train.loc[train['교통수단타입명'] == '서울순환버스', '버스타입'] = '시내버스'

# %%
train
# Out:
#          사용년월  노선번호                   노선명  표준버스정류장ID 버스정류장ARS번호  \
# 0      202209   741     741번(진관차고지~헌인릉입구)  100000001       1001
# 1      202209   470      470번(상암차고지~안골마을)  100000001       1001
# 4      202209   100        100번(하계동~용산구청)  100000002       1002
# 5      202209   107      107번(민락동차고지~동대문)  100000002       1002
# 6      202209   104  104번(강북청소년수련관난나~숭례문)  100000002       1002
# ...       ...   ...                   ...        ...        ...
# 41645  202308   672        672번(방화동~이대후문)  999800002          ~
# 41646  202308  9404       9404번(분당구미~신사역)  999800003          ~
# 41647  202308  9404       9404번(분당구미~신사역)  999800004          ~
# 41648  202308  9707    9707번(고양 가좌동~영등포역)  999800005          ~
# 41649  202308  9701        9701번(가좌동~서울역)  999800005          ~
#
#                         역명  00시승차총승객수  00시하차총승객수  1시승차총승객수  1시하차총승객수  ...  \
# 0           종로2가사거리(00077)         92         77       105       118  ...
# ...

# %% [markdown]
# ## 날씨 데이터 정리

# %%
#merge로 병합할 것을 대비, 같은 날짜 형식으로 바꾸는 과정 필요
weather_temp = weather_temp.rename(columns = {'일시':'사용년월'})

# %%
for i in range(24):
  weather_temp.loc[i, '사용년월'] = str(weather_temp.loc[i, '사용년월'][:4])+str(weather_temp.loc[i, '사용년월'][5:])

# %%
weather_temp
# Out:
#     \t\t지점번호 지점명    사용년월  평균기온(℃)  평균최고기온(℃)  최고기온(℃)    \t최고기온일자  평균최저기온(℃)  \
# 0        108  서울  202201     -2.2        2.6      8.4  2022-01-24       -6.2
# 1        108  서울  202202     -1.1        3.8     11.5  2022-02-28       -5.3
# 2        108  서울  202203      7.7       12.7     19.5  2022-03-12        3.2
# 3        108  서울  202204     14.8       20.6     28.7  2022-04-26       10.0
# 4        108  서울  202205     19.1       25.0     30.7  2022-05-23       13.9
# 5        108  서울  202206     23.3       27.5     32.7  2022-06-11       19.8
# 6        108  서울  202207     27.3       31.0     36.1  2022-07-30       24.2
# 7        108  서울  202208     25.7       28.9     32.9  2022-08-04       23.1
# 8        108  서울  202209     22.4       27.2     32.5  2022-09-18       18.2
# 9        108  서울  202210     14.6       19.7     27.6  2022-10-01       10.3
# 10       108  서울  202211     10.0       15.4     22.1  2022-11-11        5.6
# ...

# %%
#불필요한 칼럼 제거
weather_temp.drop(labels=['\t\t지점번호','지점명', '\t최고기온일자', '최저기온일자'],axis=1,inplace=True)
weather_temp
# Out:
#       사용년월  평균기온(℃)  평균최고기온(℃)  최고기온(℃)  평균최저기온(℃)  최저기온(℃)
# 0   202201     -2.2        2.6      8.4       -6.2    -11.3
# 1   202202     -1.1        3.8     11.5       -5.3    -10.7
# 2   202203      7.7       12.7     19.5        3.2     -3.0
# 3   202204     14.8       20.6     28.7       10.0      3.5
# 4   202205     19.1       25.0     30.7       13.9      7.9
# 5   202206     23.3       27.5     32.7       19.8     14.9
# 6   202207     27.3       31.0     36.1       24.2     20.8
# 7   202208     25.7       28.9     32.9       23.1     16.1
# 8   202209     22.4       27.2     32.5       18.2     12.3
# 9   202210     14.6       19.7     27.6       10.3      4.4
# 10  202211     10.0       15.4     22.1        5.6     -8.1
# 11  202212     -2.8        1.7     10.2       -6.6    -13.7
# 12  202301     -1.5        3.2     12.5       -5.7    -17.3
# 13  202302      2.3        7.3     12.4       -1.9     -5.3
# 14  202303      9.8       16.2     25.1        4.2     -1.9
# ...

# %%
weather_rain.columns
# Out:
# Index(['\t지점번호', '지점명', '일시', '강수량(mm)', '일최다강수량(mm)', '일최다강수량일자',
#        '1시간최다강수량(mm)', '1시간최다강수량일자', 'Unnamed: 8'],
#       dtype='object')

# %%
#merge로 병합할 것을 대비, 같은 날짜 형식으로 바꾸는 과정 필요
weather_rain = weather_rain.rename(columns = {'일시':'사용년월'})
for i in range(24):
  weather_rain.loc[i, '사용년월'] = str(weather_rain.loc[i, '사용년월'][:4])+str(weather_rain.loc[i, '사용년월'][5:])
#불필요한 칼럼 제거
weather_rain.drop(labels=['\t지점번호','지점명', '일최다강수량일자', '1시간최다강수량(mm)', '1시간최다강수량일자', 'Unnamed: 8'],axis=1,inplace=True)
weather_rain
# Out:
#       사용년월  강수량(mm)  일최다강수량(mm)
# 0   202201      5.5         1.7
# 1   202202      4.7         1.7
# 2   202203    102.6        42.1
# 3   202204     20.4        15.5
# 4   202205      7.5         3.5
# 5   202206    393.8       176.2
# 6   202207    252.3       114.5
# 7   202208    564.8       129.6
# 8   202209    201.5       120.0
# 9   202210    124.1        76.0
# 10  202211     84.5        57.9
# 11  202212     13.6         5.4
# 12  202301     47.9        37.3
# 13  202302      1.0         0.6
# 14  202303     10.5         5.6
# 15  202304     96.9        50.3
# 16  202305    155.6        47.5
# 17  202306    195.6        63.8
# 18  202307    459.9        91.6
# 19  202308    298.1        86.1
# 20  202309    134.5        38.7
# 21  202310     31.0        14.7
# 22  202311     81.9        45.8
# 23  202312     85.9        31.1

# %% [markdown]
# ## 데이터 병합

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 450530 entries, 0 to 41649
# Data columns (total 56 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   사용년월        450530 non-null  int64
#  1   노선번호        450530 non-null  object
#  2   노선명         450530 non-null  object
#  3   표준버스정류장ID   450530 non-null  int64
#  4   버스정류장ARS번호  450530 non-null  object
#  5   역명          450530 non-null  object
#  6   00시승차총승객수   450530 non-null  int64
#  7   00시하차총승객수   450530 non-null  int64
#  8   1시승차총승객수    450530 non-null  int64
#  9   1시하차총승객수    450530 non-null  int64
#  10  2시승차총승객수    450530 non-null  int64
#  11  2시하차총승객수    450530 non-null  int64
#  12  3시승차총승객수    450530 non-null  int64
#  13  3시하차총승객수    450530 non-null  int64
#  14  4시승차총승객수    450530 non-null  int64
#  15  4시하차총승객수    450530 non-null  int64
#  16  5시승차총승객수    450530 non-null  int64
#  17  5시하차총승객수    450530 non-null  int64
# ...

# %%
weather_rain.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 24 entries, 0 to 23
# Data columns (total 3 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   사용년월        24 non-null     object
#  1   강수량(mm)     24 non-null     float64
#  2   일최다강수량(mm)  24 non-null     float64
# dtypes: float64(2), object(1)
# memory usage: 704.0+ bytes

# %%
weather_temp['사용년월'] = weather_temp['사용년월'].astype(int)
weather_rain['사용년월'] = weather_rain['사용년월'].astype(int)

# %%
#날씨_온도 데이터 추가
train = pd.merge(train,weather_temp, how='inner',on='사용년월')
train
# Out:
#           사용년월  노선번호                   노선명  표준버스정류장ID 버스정류장ARS번호  \
# 0       202209   741     741번(진관차고지~헌인릉입구)  100000001       1001
# 1       202209   470      470번(상암차고지~안골마을)  100000001       1001
# 2       202209   100        100번(하계동~용산구청)  100000002       1002
# 3       202209   107      107번(민락동차고지~동대문)  100000002       1002
# 4       202209   104  104번(강북청소년수련관난나~숭례문)  100000002       1002
# ...        ...   ...                   ...        ...        ...
# 450525  202308   672        672번(방화동~이대후문)  999800002          ~
# 450526  202308  9404       9404번(분당구미~신사역)  999800003          ~
# 450527  202308  9404       9404번(분당구미~신사역)  999800004          ~
# 450528  202308  9707    9707번(고양 가좌동~영등포역)  999800005          ~
# 450529  202308  9701        9701번(가좌동~서울역)  999800005          ~
#
#                          역명  00시승차총승객수  00시하차총승객수  1시승차총승객수  1시하차총승객수  ...  \
# 0            종로2가사거리(00077)         92         77       105       118  ...
# ...

# %%
#날씨_강수량 데이터 추가
train = pd.merge(train,weather_rain, how='inner',on='사용년월')
train
# Out:
#           사용년월  노선번호                   노선명  표준버스정류장ID 버스정류장ARS번호  \
# 0       202209   741     741번(진관차고지~헌인릉입구)  100000001       1001
# 1       202209   470      470번(상암차고지~안골마을)  100000001       1001
# 2       202209   100        100번(하계동~용산구청)  100000002       1002
# 3       202209   107      107번(민락동차고지~동대문)  100000002       1002
# 4       202209   104  104번(강북청소년수련관난나~숭례문)  100000002       1002
# ...        ...   ...                   ...        ...        ...
# 450525  202308   672        672번(방화동~이대후문)  999800002          ~
# 450526  202308  9404       9404번(분당구미~신사역)  999800003          ~
# 450527  202308  9404       9404번(분당구미~신사역)  999800004          ~
# 450528  202308  9707    9707번(고양 가좌동~영등포역)  999800005          ~
# 450529  202308  9701        9701번(가좌동~서울역)  999800005          ~
#
#                          역명  00시승차총승객수  00시하차총승객수  1시승차총승객수  1시하차총승객수  ...  \
# 0            종로2가사거리(00077)         92         77       105       118  ...
# ...

# %%
#test에도 동일하게 수행.
test = pd.merge(test,weather_temp, how='inner',on='사용년월')
test = pd.merge(test,weather_rain, how='inner',on='사용년월')
test
# Out:
#           사용년월  노선번호                      노선명  표준버스정류장ID 버스정류장ARS번호  \
# 0       202309   470         470번(상암차고지~안골마을)  100000001       1001
# 1       202309   741        741번(진관차고지~헌인릉입구)  100000001       1001
# 2       202309   100           100번(하계동~용산구청)  100000002       1002
# 3       202309   104     104번(강북청소년수련관난나~숭례문)  100000002       1002
# 4       202309   171  171번(용마문화복지센터~월드컵파크7단지)  100000002       1002
# ...        ...   ...                      ...        ...        ...
# 113141  202311   672           672번(방화동~이대후문)  999800002          ~
# 113142  202311  9404          9404번(분당구미~신사역)  999800003          ~
# 113143  202311  9404          9404번(분당구미~신사역)  999800004          ~
# 113144  202311  9701           9701번(가좌동~서울역)  999800005          ~
# 113145  202311  9707       9707번(고양 가좌동~영등포역)  999800005          ~
#
#                          역명  00시승차총승객수  00시하차총승객수  1시승차총승객수  1시하차총승객수  ...  \
# ...

# %% [markdown]
# ## 사람 가장 많은 시간은??

# %%
train.describe()
# Out:
#                 사용년월     표준버스정류장ID      00시승차총승객수      00시하차총승객수  \
# count  450530.000000  4.505300e+05  450530.000000  450530.000000
# mean   202273.369019  1.277918e+08      20.638228      27.313322
# std        44.294997  7.158135e+07      69.704085      60.443047
# min    202209.000000  1.000000e+08       0.000000       0.000000
# 25%    202212.000000  1.080001e+08       0.000000       0.000000
# 50%    202303.000000  1.149001e+08       0.000000       1.000000
# 75%    202306.000000  1.210002e+08      11.000000      27.000000
# max    202308.000000  9.998000e+08    2412.000000    1644.000000
#
#             1시승차총승객수       1시하차총승객수       2시승차총승객수       2시하차총승객수  \
# count  450530.000000  450530.000000  450530.000000  450530.000000
# mean        2.274037       4.262466       0.180663       0.373928
# std        16.813408      21.551355       3.579896       4.770978
# min         0.000000       0.000000       0.000000       0.000000
# ...

# %%
train.describe()
test.describe()
# Out:
#                 사용년월     표준버스정류장ID      00시승차총승객수      00시하차총승객수  \
# count  113146.000000  1.131460e+05  113146.000000  113146.000000
# mean   202309.999867  1.275631e+08      21.278905      28.333030
# std         0.814074  7.152415e+07      72.444271      63.936631
# min    202309.000000  1.000000e+08       0.000000       0.000000
# 25%    202309.000000  1.080001e+08       0.000000       0.000000
# 50%    202310.000000  1.149000e+08       0.000000       0.000000
# 75%    202311.000000  1.210002e+08      11.000000      27.000000
# max    202311.000000  9.998000e+08    2345.000000    1898.000000
#
#             1시승차총승객수       1시하차총승객수       2시승차총승객수       2시하차총승객수  \
# count  113146.000000  113146.000000  113146.000000  113146.000000
# mean        2.199212       4.294708       0.164822       0.350008
# std        16.288591      22.421722       3.588329       4.671028
# min         0.000000       0.000000       0.000000       0.000000
# ...

# %%
sns.barplot(x = '사용년월', y = '18시승차총승객수',  data = train, estimator = np.mean)
# Out:
# <Axes: xlabel='사용년월', ylabel='18시승차총승객수'>
# /usr/local/lib/python3.10/dist-packages/IPython/core/events.py:89: UserWarning: Glyph 49324 (\N{HANGUL SYLLABLE SA}) missing from current font.
#   func(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/IPython/core/events.py:89: UserWarning: Glyph 50857 (\N{HANGUL SYLLABLE YONG}) missing from current font.
#   func(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/IPython/core/events.py:89: UserWarning: Glyph 45380 (\N{HANGUL SYLLABLE NYEON}) missing from current font.
#   func(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/IPython/core/events.py:89: UserWarning: Glyph 50900 (\N{HANGUL SYLLABLE WEOL}) missing from current font.
#   func(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/IPython/core/events.py:89: UserWarning: Glyph 49884 (\N{HANGUL SYLLABLE SI}) missing from current font.
#   func(*args, **kwargs)
# ...

# %%
sns.distplot(train['18시승차총승객수'], rug=True)
# Out:
# <ipython-input-59-b8c5e5c6a6de>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(train['18시승차총승객수'], rug=True)
# <Axes: xlabel='18시승차총승객수', ylabel='Density'>
# /usr/local/lib/python3.10/dist-packages/IPython/core/events.py:89: UserWarning: Glyph 49884 (\N{HANGUL SYLLABLE SI}) missing from current font.
#   func(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/IPython/core/events.py:89: UserWarning: Glyph 49849 (\N{HANGUL SYLLABLE SEUNG}) missing from current font.
#   func(*args, **kwargs)
# ...

# %%
 sns.heatmap(data = train["00시승차총승객수":'23시하차총승객수'].corr(method = 'pearson'))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-61-aa4173d6d52f> in <cell line: 1>()
# ----> 1 sns.heatmap(data = train["00시승차총승객수":'23시하차총승객수'].corr(method = 'pearson'))
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in __getitem__(self, key)
#    3777                 return self._getitem_multilevel(key)
#    3778         # Do we have a slicer (on rows)?
# -> 3779         indexer = convert_to_index_sliceable(self, key)
#    3780         if indexer is not None:
#    3781             if isinstance(indexer, np.ndarray):
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexing.py in convert_to_index_sliceable(obj, key)
#    2492     idx = obj.index
#    2493     if isinstance(key, slice):
# -> 2494         return idx._convert_slice_indexer(key, kind="getitem")
#    2495
#    2496     elif isinstance(key, str):
#
# ...
